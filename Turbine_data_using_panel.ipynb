# %%
import holoviews as hv
import hvplot.pandas
import intake
import panel as pn

hv.streams.PlotSize.scale = 0.2

pn.extension('tabulator', design='material', template='material', theme='dark')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
cat = intake.open_anaconda_catalog('examples')['uswtdb']

df = pn.state.as_cached('windturbines', cat.wind_turbines.read)

df['x'], df['y'] = hv.element.tiles.lon_lat_to_easting_northing(df.xlong, df.ylat)

df.head()
# Out:
#      case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0  3072695.0        NaN               NaN      5143.0  52161.0      CA
# 1  3072661.0        NaN               NaN      5149.0  52161.0      CA
# 2  3072704.0        NaN               NaN      5146.0  52161.0      CA
# 3  3063269.0  19-028130  2016-WTE-5934-OE         NaN      NaN      IA
# 4  3057059.0  19-027954  2016-WTE-9485-OE         NaN      NaN      IA
#
#        t_county   t_fips                   p_name  p_year  ...  retrofit  \
# 0   Kern County   6029.0                 251 Wind  1987.0  ...       0.0
# 1   Kern County   6029.0                 251 Wind  1987.0  ...       0.0
# 2   Kern County   6029.0                 251 Wind  1987.0  ...       0.0
# 3  Story County  19169.0  30 MW Iowa DG Portfolio  2017.0  ...       0.0
# 4  Story County  19169.0  30 MW Iowa DG Portfolio  2017.0  ...       0.0
#
#    retrofit_year t_conf_atr t_conf_loc  t_img_date     t_img_srce       xlong  \
# 0            NaN        2.0        3.0    5/8/2018  Digital Globe -118.364410
# 1            NaN        2.0        3.0    5/8/2018  Digital Globe -118.363762
# 2            NaN        2.0        3.0    5/8/2018  Digital Globe -118.364197
# 3            NaN        3.0        3.0   7/23/2017  Digital Globe  -93.632835
# 4            NaN        3.0        3.0   5/13/2017  Digital Globe  -93.623009
#
#         ylat             x             y
# 0  35.077435 -1.317627e+07  4.174409e+06
# 1  35.077908 -1.317619e+07  4.174474e+06
# 2  35.077644 -1.317624e+07  4.174438e+06
# 3  41.882477 -1.042316e+07  5.143391e+06
# 4  41.881470 -1.042207e+07  5.143241e+06
#
# [5 rows x 29 columns]

# %%
import pandas as pd
import numpy as np
import holoviews as hv
from holoviews import opts
import hvplot.pandas  # Ensure hvplot is available

# Initialize Holoviews extension for Jupyter
hv.extension('bokeh')

# Create a DataFrame with random data
np.random.seed(42)
df = pd.DataFrame({
    'x': np.random.rand(100),
    'y': np.random.rand(100)
})

# Initialize link selections
ls = hv.link_selections.instance()

# Create a plot with interactive linked selections
# Removed the tiles parameter to avoid issues with geoviews and cartopy
plot = df.hvplot.points('x', 'y', rasterize=True, cmap='viridis', cnorm='eq_hist', 
                        xaxis=None, yaxis=None, responsive=True, min_height=500)

# Apply linked selections to the plot
plot_ls = ls(plot)

plot_ls
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :DynamicMap   []
#    :Overlay
#       .Image.I      :Image   [x,y]   (x_y Count)
#       .Image.II     :Image   [x,y]   (x_y Count)
#       .Rectangles.I :Rectangles   [x0,y0,x1,y1]
#       .Path.I       :Path   [x,y]

# %%
import pandas as pd
import numpy as np
import holoviews as hv
import hvplot.pandas  # Import hvplot for pandas
import panel as pn  # Ensure panel is imported

hv.extension('bokeh')

# Assuming df is already defined and has the correct columns.
# Example to simulate the existence of the DataFrame with specified columns:
np.random.seed(42)
df = pd.DataFrame({
    't_state': np.random.choice(['State1', 'State2', 'State3'], 100),
    't_county': np.random.choice(['County1', 'County2', 'County3'], 100),
    't_manu': np.random.choice(['Manufacturer1', 'Manufacturer2', 'Manufacturer3'], 100),
    'p_year': np.random.randint(1990, 2021, 100),
    'p_name': np.random.choice(['Product1', 'Product2', 'Product3'], 100),
    'p_cap': np.random.rand(100) * 100
})

ls = hv.link_selections.instance()  # Initialize linked selections
df_sel = ls.selection_param(df)

# Create a dynamic interactive view
dfi_sel = hvplot.bind(lambda df: df, df_sel).interactive()[['t_state', 't_county', 't_manu', 'p_year', 'p_name', 'p_cap']]

# Setup a Tabulator widget with remote pagination
table = pn.widgets.Tabulator(dfi_sel, pagination='remote', page_size=10, sizing_mode='stretch_width', show_index=True)

table
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# Tabulator(design=<class 'panel.theme.materi..., page_size=10, pagination='remote', sizing_mode='stretch_width', value=   t_state t_county  ...)

# %%
groupby = pn.widgets.RadioButtonGroup(options=['p_year', 't_state', 't_manu'])
topn = pn.widgets.IntSlider(start=5, end=50, name='Top N')

agg_bar_plot = dfi_sel.groupby(groupby)[['p_cap']].sum().sort_values('p_cap', ascending=False).iloc[:topn].hvplot.bar(rot=45, responsive=True, min_height=300)

agg_bar_plot
# Out:
# <div id='8b435727-6ab6-4323-a5f5-02926b7dd04e'>
#   <div id="f76816fa-a1ee-4c2d-acc7-b8a4411490ef" data-root-id="8b435727-6ab6-4323-a5f5-02926b7dd04e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ff18f80c-7d5d-45a6-a3c9-6b60bc70c08f":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"8b435727-6ab6-4323-a5f5-02926b7dd04e","attributes":{"name":"Row06541","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"0641400b-f5f3-45d7-86e3-454aa55ba9f3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ccdd8096-992f-47ef-b066-801661d887f7","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1cc5786f-f36c-40a5-abd0-446a6a3a3019","attributes":{"url":"https://cdn.jsdelivr.net/npm/material-components-web@7.0.0/dist/material-components-web.min.css"}},{"type":"object","name":"ImportedStyleSheet","id":"159586a6-9be4-4f2a-bb4e-16498c353c21","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/dark.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ce1d1465-c5fe-4a80-adbd-0d6a7483334f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/material_variables.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c3dd4ea3-1dc5-4b06-909e-4dbd2170902f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/material.css"}}],"min_height":300,"margin":0,"sizing_mode":"stretch_both","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"d8086a89-dfd4-442e-9f53-f7d5f79e5f0c","attributes":{"name":"Column06538","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0641400b-f5f3-45d7-86e3-454aa55ba9f3"},{"id":"ccdd8096-992f-47ef-b066-801661d887f7"},{"id":"1cc5786f-f36c-40a5-abd0-446a6a3a3019"},{"id":"159586a6-9be4-4f2a-bb4e-16498c353c21"},{"id":"ce1d1465-c5fe-4a80-adbd-0d6a7483334f"},{"id":"c3dd4ea3-1dc5-4b06-909e-4dbd2170902f"}],"min_height":300,"margin":0,"sizing_mode":"stretch_both","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"f6682d4a-3abb-48cd-bebf-5aebf0f9ad93","attributes":{"name":"Column06521","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0641400b-f5f3-45d7-86e3-454aa55ba9f3"},{"id":"ccdd8096-992f-47ef-b066-801661d887f7"},{"id":"1cc5786f-f36c-40a5-abd0-446a6a3a3019"},{"id":"159586a6-9be4-4f2a-bb4e-16498c353c21"},{"id":"ce1d1465-c5fe-4a80-adbd-0d6a7483334f"},{"id":"c3dd4ea3-1dc5-4b06-909e-4dbd2170902f"}],"margin":0,"align":"start","children":[{"type":"object","name":"RadioButtonGroup","id":"6264bf3c-a6e6-4307-8ef1-97ced1e6e5d4","attributes":{"css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"0641400b-f5f3-45d7-86e3-454aa55ba9f3"},{"type":"object","name":"ImportedStyleSheet","id":"ae220c93-f5a9-4260-ae35-b6abc2e2b91c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"1cc5786f-f36c-40a5-abd0-446a6a3a3019"},{"id":"159586a6-9be4-4f2a-bb4e-16498c353c21"},{"id":"ce1d1465-c5fe-4a80-adbd-0d6a7483334f"},{"id":"c3dd4ea3-1dc5-4b06-909e-4dbd2170902f"}],"margin":[5,10],"align":"start","labels":["p_year","t_state","t_manu"],"active":0}},{"type":"object","name":"Slider","id":"3db9ccba-1b12-4757-9eb3-47c9c5f9842d","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%,  ...

# %%
pn.Column(
    plot_ls,
    pn.Row(
        table, agg_bar_plot.layout(sizing_mode='stretch_width')
    )
).servable(title='Windturbine Dashboard')
# Out:
# Column(design=<class 'panel.theme.materi...)
#     [0] HoloViews(DynamicMap, design=<class 'panel.theme.materi..., sizing_mode='stretch_both')
#     [1] Row(design=<class 'panel.theme.materi...)
#         [0] Tabulator(design=<class 'panel.theme.materi..., page=2, page_size=10, pagination='remote', sizing_mode='stretch_width', value=   t_state t_county  ...)
#         [1] Row(design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#             [0] Column(design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#                 [0] Column(design=<class 'panel.theme.materi...)
#                     [0] RadioButtonGroup(design=<class 'panel.theme.materi..., options=['p_year', 't_state', ...], value='t_manu')
#                     [1] IntSlider(design=<class 'panel.theme.materi..., end=50, name='Top N', start=5, value=5)
#                 [1] HoloViews(DynamicMap, design=<class 'panel.theme.materi..., sizing_mode='stretch_both')
